# %% [markdown]
# # Georgia Tech Summer 2025 MSA Practicum Project
#
# ### Exploratory Data Analysis Outline
#
# **Due June 12, 2025, 12 pm ET**
#
# ---
#
#
# ## 📦 Deliverable: Exploratory Data Analysis (EDA) Notebook
#
# Each team must submit a polished, well-documented EDA notebook that communicates insights to both technical and non-technical audiences.
#
# ### ✅ Submission Instructions
#
# * Submit a **Python notebook (`EDA.ipynb`)**
# * Save it inside a folder named `deliverables` at your repo’s root
# * Set the notebook **title** (first cell) to:
#   `{GitHubTeamName} BTC EDA`
# * Push to your **private GitHub repo** by:
#   **June 12, 2025 – 12 PM ET**
#
# ---
#
# ## 📋 Notebook Structure
#
# ### 1. Executive Summary
#
# * Begin with a brief, bullet-point summary of your most novel and non-trivial findings.
#
# ### 2. Narrative-Driven Analysis
#
# * Use clear **section headers** (`#`, `##`, `###`) to guide the reader.
# * Present your EDA as a story — explain your approach, decisions, and discoveries.
#
# ### 3. Data Retrieval
#
# * Use the official [data retrieval script](https://github.com/TrilemmaFoundation/GT-MSA-S25/blob/main/2.%20Data%20Retrieval.ipynb) to load your dataset.
#
# ### 4. General Overview
#
# * Provide a high-level summary of the dataset:
#
#   * Data integrity checks
#   * Data types, value ranges, and completeness
#   * Basic descriptive statistics and exploratory plots
#
# ### 5. Focused Exploration
#
# * Deep dive into features or feature groups you find interesting:
#
#   * Justify your selection
#   * Provide statistical and visual analysis
#   * Summarize findings
#
# > Your exploration should lead to one of two conclusions:
# >
# > * ✅ "There appears to be signal worth modeling" **(preferred)**
# > * ❌ "No signal found here (but still informative)"
#
# ### 6. Showcase Your Insight
#
# * This is your chance to shine.
#   Highlight your unique thinking through:
#
#   * Rigorous statistical analysis
#   * Creative visualizations
#   * Unusual but meaningful metrics or techniques
#
# ---
#
# ## 📊 Evaluation Rubric
#
# | Category                  | Description                                                                         |
# | ------------------------- | ----------------------------------------------------------------------------------- |
# | **Readability**           | Can a layperson follow the high-level narrative?                                    |
# | **Technical Depth**       | Are the methods and findings clear enough for another data scientist to build upon? |
# | **Visualization Quality** | Are your plots informative, clean, and properly labeled (no default styling)?       |
# | **Statistical Rigor**     | Do you explore deeper signals (e.g., autocorrelation, stationarity, seasonality)?   |
# | **Executive Summary**     | Is your summary concise, insightful, and non-trivial?                               |
# | **Engagement**            | Is your notebook interesting to explore? Link to side notebooks if needed.          |
# | **Reproducibility**       | Can the notebook be run top-to-bottom without confusion or missing context?         |
#
# ---
#
# ### 🚀 Success Tips
#
# * Use strong titles and captions to enhance the reader’s understanding.
# * Prioritize clarity and insight over code quantity.
# * Write with the assumption that your audience has **5 minutes** to review your work.
# * Link out to deeper analyses pushed as separate notebooks on GitHub** to avoid cluttering the main notebook:
#
#   > *See* [`monte_carlo_deep_dive.ipynb`](../monte_carlo_deep_dive.ipynb) *for detailed tests.*
