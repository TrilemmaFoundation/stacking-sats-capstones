# %% [markdown]
# # [Trilemma Foundation](https://www.trilemma.foundation/) x [Strategy](https://www.strategy.com/) Stacking Sats Tournament
#
# **Hosted on [Hypertrial.ai](https://www.hypertrial.ai/bitcoin-arena/challenge/bitcoin)**
#
# ### Educational Notebook Outline
#
# ---

# %% [markdown]
# # 📦 Deliverable: Final Educational Notebook
#
# > 🧠 Think of this notebook as a **take-home assignment** for a research role at a fund.
# > Reviewers will assess both your **modeling skill** and your ability to **communicate clearly**.
#
# Each team must submit a polished, well-documented notebook that communicates your accumulation model clearly to both technical and non-technical audiences.
#
# ---
#
# ## ✅ Submission Instructions
#
# - Submit a **Python notebook** named `btc_accumulation_model.ipynb`
# - Save it in a folder called `deliverables` at the root of your GitHub repo
# - Title the notebook (first markdown cell) to reflect your strategy
#   *Example: `Optimal Bitcoin Accumulation via a 200-day MA Model`*
# - Push to your **GitHub repo** by the deadline
# - **Do not commit** anything to the repo after the deadline—they will not count
#
# ---
#
# ## 📓 Notebook Structure
#
# ### 1. Executive Summary
#
# - Summarize your **modeling approach**
# - Highlight key **Exploratory Data Analysis (EDA) insights** that led to your strategy
# - Discuss the strengths and limitations of your model referencing its `Final Model Score` (derived from model_development_template.ipynb)
# - Use **quantitative evidence** to support claims (e.g., “Our model beat uniform DCA in 61% of windows”)
# - Keep it concise and understandable without deep technical detail
#
# ---
#
# ### 2. 📊 Exploratory Data Analysis Highlights
#
# * Showcase the key **EDA insights** that directly shaped your model
# * This section should be **visual**. We want to **see** your analysis, not just read about it
#
#   * Use **plots**, **charts**, and **figures** to make your insights tangible
#   * Insert visuals generated during your EDA using markdown image links:
#
#     ```markdown
#     ![Plot Title](path/to/your/image.png)
#     ```
# * Link to the full EDA notebook for a deeper dive into the data and code behind the visuals
#
#   > [`eda_notebook.ipynb`](path/to/eda_notebook.ipynb)
#
# ---
#
# Let me know if you'd like an example plot embedded.
#
#
# ---
#
# ### 3. 🧠 Model Explanation
#
# - Explain your final strategy:
#   - What features it uses
#   - How it makes decisions
#   - Why it performs better than uniform DCA
#   - Why it should generalize well to future unseen data
#   - Ideas for future improvement
# - Link to your full model implementation (pushed to the same GitHub repo):
#   > [`model_development_template.ipynb`](https://github.com/TrilemmaFoundation/stacking-sats-tournament-mstr-2025/blob/main/model-development/model_development_template.ipynb)
#
# ---
#
# ## 🛠️ Model Development Notebook (External)
#
# > 📌 Use the template notebook above to build and evaluate your strategy.
#
# ### 🔧 Steps
#
# 1. Clone the template notebook
# 2. Define your features inside `construct_features()` under `✍️ User Code`
# 3. Write your model logic inside `compute_weights()` under `✍️ User Code`
# 4. Run all cells top-to-bottom
# 5. You must see this at the end:
#    ```✅ Strategy is ready for submission.```
# 6. You may keep your repository private during the tournament to protect your work, but you must make it public immediately after the final submission deadline to be eligible for evaluation.
#
# ---
#
# ### ✅ Model Requirements
#
# Your model must:
#
# - Use **only past and current data** (no forward-looking features)
# - Output weights that:
#   - Are all **positive**
#   - Are all **≥ MIN_WEIGHT**
#   - **Sum to 1** in each window
# - **Outperform or match** uniform DCA in **at least 50%** of rolling windows
# - **Not modify boilerplate code**
#
# > ⚠️ Modifying any of the boilerplate code (e.g., helper functions, evaluation logic) will result in disqualification.
# > You may ignore parts of the boilerplate that don't generalize to your feature set (e.g., plotting logic).
#
# ---
#
# ## 📊 Evaluation Rubric
#
# | Category                | Description                                                                 |
# | ----------------------- | --------------------------------------------------------------------------- |
# | **Readability**         | Clear structure, strong use of markdown, accessible explanations            |
# | **Technical Depth**     | Demonstrates rigor, sound logic, and relevant domain insight                |
# | **Novel & Non-trivial** | Strategy shows creativity or meaningful improvement over simple baselines  |
# | **Valid Model**         | Passes all strategy checks without modifying restricted boilerplate         |
# | **Outline Points Met**  | Notebook includes all required sections and links to supporting notebooks   |
#
#
# > 📌 **Note on Evaluation Philosophy:**
# > This deliverable is designed to emphasize exploration, creativity, and clear communication in tackling a complex problem. Unlike the model code deliverable, where ranking is based on the final model score, this notebook is evaluated independently of performance.
# >
# > As long as your model is valid, we will focus on how well you analyze, explain, and present your work—not just how well it performs numerically.
#
# ---
#
# ## 🚀 Success Tips
#
# - 🧠 Your notebook should have a **30-second takeaway**: readers should quickly grasp the core idea
# - 🔬 It should also support **deep dives**: link your EDA and development notebooks for those wanting details
# - ✨ Prioritize **visual polish**: clean plots, labeled axes, well-formatted markdown, and consistent layout
#
# ---
#
# ## ✅ Final Checklist
#
# - [ ] Notebook file named `btc_accumulation_model.ipynb`
# - [ ] Notebook saved in `deliverables/` folder
# - [ ] Executive Summary is clear and concise
# - [ ] Model passes all validation checks
# - [ ] No commits made after the submission deadline
